# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # load data

# %%
pre_trace = np.load('pre_trace.npy')
post_traces = np.load('post_traces.npy')

# %%
fig, axs = plt.subplots(2, 6, dpi=500, figsize=(12, 8))
for i, ax in enumerate(axs[0]):
    ax.imshow(np.repeat(pre_trace[i][None, :], 5, axis=0), cmap='binary')
    ax.set_xticks([])
    ax.set_yticks([])
for i, ax in enumerate(axs[1]):
    obj = ax.imshow(post_traces[:100, i], cmap='binary')
    ax.set_xticks([])
    ax.set_yticks([])
fig.set_tight_layout('tight')
# fig.colorbar(obj, location='bottom')
